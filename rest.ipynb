# %%
import pandas as pd
import requests

# %%
r = requests.get("https://broker-ld.fiware.dev.urbanplatform.portodigital.pt/v2/entities?q=vehicleType==bus")
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# [{'id': 'urn:ngsi-ld:Vehicle:porto:stcp:bus:3357',
#   'type': 'Vehicle',
#   'annotations': {'type': 'Array',
#    'value': ['stcp%3Aroute%3A204',
#     'stcp%3Anr_turno%3A3',
#     'stcp%3Anr_viagem%3A8',
#     'stcp%3Asentido%3A0'],
#    'metadata': {}},
#   'category': {'type': 'Array',
#    'value': ['municipalServices', 'tracked'],
#    'metadata': {}},
#   'dataProvider': {'type': 'Text', 'value': 'Veniam', 'metadata': {}},
#   'fleetVehicleId': {'type': 'Text', 'value': '3357', 'metadata': {}},
#   'heading': {'type': 'Number', 'value': 243.12, 'metadata': {}},
#   'location': {'type': 'geo:json',
#    'value': {'type': 'Point', 'coordinates': [-8.63074, 41.165016]},
#    'metadata': {}},
#   'serviceProvided': {'type': 'Array',
#    'value': ['urbanTransit'],
#    'metadata': {}},
#   'source': {'type': 'Text',
#    'value': 'http%3A//mapserver.stcp.pt%3A50081/InfoRedeSTCPCMP.asmx%3Fwsdl',
#    'metadata': {}},
#   'speed': {'type': 'Number', 'value': 20, 'metadata': {}},
# ...
